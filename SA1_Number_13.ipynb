# %% [markdown]
# <a href="https://colab.research.google.com/github/Chuuya1124/APM1201/blob/main/SA1_Number_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Perform experimental analysis to test the hypothesis that Python’s sorted method runs in O(nlogn) time on average

# %%
import time
import random
import matplotlib.pyplot as plt
import numpy as np

def measure_time(n):
    lst = random.sample(range(n), n)
    start = time.time()
    sorted(lst)
    return time.time() - start

sizes = [2**i for i in range(11, 24)]
times = [measure_time(n) for n in sizes]  #

##Plot actual sorting times
plt.plot(sizes, times, label='Actual Time', marker='o')

nlogn = [n * np.log2(n) / 1e6 for n in sizes]
plt.plot(sizes, nlogn, label='O(n log n)', linestyle='--')

plt.xscale('log')
plt.yscale('log')
plt.xlabel('Input Size (n)')
plt.ylabel('Time (seconds)')
plt.title('Python sorted() Time Complexity')
plt.legend()
plt.grid(True)

plt.show()
